# %%
from thompson import *

# %%
x = """30
(2, 12)   -> (2, 12)
x1  a1 a1 -> x7  a1 a2
x1  a1 a2 -> x8  a2 a1
x1  a2 a1 -> x9  a2 a2
x1  a2 a2 -> x1
x2  a1 a1 -> x8  a1 a2
x2  a1 a2 -> x7  a2 a1
x2  a2 a1 -> x12 a2 a2
x2  a2 a2 -> x2
x3  a1 a1 -> x9  a1 a2
x3  a1 a2 -> x10 a2 a1
x3  a2 a1 -> x11 a2 a2
x3  a2 a2 -> x3
x4  a1 a1 -> x10 a1 a2
x4  a1 a2 -> x9  a2 a1
x4  a2 a1 -> x8  a2 a2
x4  a2 a2 -> x4
x5  a1 a1 -> x11 a1 a2
x5  a1 a2 -> x12 a2 a1
x5  a2 a1 -> x7  a2 a2
x5  a2 a2 -> x5
x6  a1 a1 -> x12 a1 a2
x6  a1 a2 -> x11 a2 a1
x6  a2 a1 -> x10 a2 a2
x6  a2 a2 -> x6
x7        -> x7  a1 a1
x8        -> x8  a1 a1
x9        -> x9  a1 a1
x10       -> x10 a1 a1
x11       -> x11 a1 a1
x12       -> x12 a1 a1 
"""
a = Automorphism.from_string(x)
forest(a, horiz=False, name=r"$\alpha$")

# %%
y = """12
(2, 12)   -> (2, 12)
x1        -> x2
x2        -> x1
x3        -> x6
x4        -> x5
x5        -> x4
x6        -> x3
x7        -> x8
x8        -> x7
x9        -> x12
x10       -> x11
x11       -> x10
x12       -> x9
"""
g = Automorphism.from_string(y)
forest(g, horiz=False)

# %%
g*a == a*g
# Out:
# True

# %%
z = """12
(2, 12)   -> (2, 12)
x1        -> x3
x2        -> x4
x3        -> x5
x4        -> x6
x5        -> x1
x6        -> x2
x7        -> x9
x8        -> x10
x9        -> x11
x10       -> x12
x11       -> x7
x12       -> x8
"""
h = Automorphism.from_string(z)
forest(h, horiz=False)

# %%
h*a == a*h
# Out:
# True

# %%
h*g == g*h
# Out:
# False

# %%
g.order
# Out:
# 2

# %%
h.order
# Out:
# 3
